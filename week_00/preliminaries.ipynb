# %% [markdown]
# # Get Ready for BUSN 30135
# In preparation for our first lab, there are a few steps every student should take before the lab:
# 1. Installing basic Python packages
# 2. Create an account on HuggingFace
# 3. Request access to Meta's latest models and download them
# ## 1. Install Python Packages
# We will rely on a variety of Python packages during lab. The included `requirements.txt` file enumerates those needed for the early labs. Install these packages by running the following code cell in this Jupyter notebook:

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: accelerate==1.2.1 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (1.2.1)
# Requirement already satisfied: asttokens==3.0.0 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: bitsandbytes==0.45.0 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (0.45.0)
# Requirement already satisfied: certifi==2024.12.14 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (2024.12.14)
# Requirement already satisfied: charset-normalizer==3.4.0 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (3.4.0)
# Requirement already satisfied: comm==0.2.2 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (0.2.2)
# Requirement already satisfied: debugpy==1.8.11 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (1.8.11)
# Requirement already satisfied: decorator==5.1.1 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (5.1.1)
# Requirement already satisfied: exceptiongroup==1.2.2 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (1.2.2)
# Requirement already satisfied: executing==2.1.0 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (2.1.0)
# Requirement already satisfied: filelock==3.16.1 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 11)) (3.16.1)
# Requirement already satisfied: fsspec==2024.10.0 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 12)) (2024.10.0)
# Requirement already satisfied: huggingface-hub==0.27.0 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 13)) (0.27.0)
# Requirement already satisfied: idna==3.10 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 14)) (3.10)
# Requirement already satisfied: ipykernel==6.29.5 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 15)) (6.29.5)
# Requirement already satisfied: ipython==8.30.0 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 16)) (8.30.0)
# Requirement already satisfied: ipywidgets==8.1.5 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 17)) (8.1.5)
# Requirement already satisfied: jedi==0.19.2 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 18)) (0.19.2)
# Requirement already satisfied: Jinja2==3.1.3 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 19)) (3.1.3)
# Requirement already satisfied: jupyter_client==8.6.3 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 20)) (8.6.3)
# Requirement already satisfied: jupyter_core==5.7.2 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 21)) (5.7.2)
# Requirement already satisfied: jupyterlab_widgets==3.0.13 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 22)) (3.0.13)
# Requirement already satisfied: MarkupSafe==2.1.5 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 23)) (2.1.5)
# Requirement already satisfied: matplotlib-inline==0.1.7 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 24)) (0.1.7)
# Requirement already satisfied: mpmath==1.3.0 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 25)) (1.3.0)
# Requirement already satisfied: nest-asyncio==1.6.0 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 26)) (1.6.0)
# Requirement already satisfied: networkx==3.2.1 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 27)) (3.2.1)
# Requirement already satisfied: numpy==2.2.0 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 28)) (2.2.0)
# Requirement already satisfied: packaging==24.2 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 29)) (24.2)
# Requirement already satisfied: pandas==2.2.3 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 30)) (2.2.3)
# Requirement already satisfied: parso==0.8.4 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 31)) (0.8.4)
# Requirement already satisfied: pexpect==4.9.0 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 32)) (4.9.0)
# Requirement already satisfied: pillow==10.2.0 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 33)) (10.2.0)
# Requirement already satisfied: platformdirs==4.3.6 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 34)) (4.3.6)
# Requirement already satisfied: prompt_toolkit==3.0.48 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 35)) (3.0.48)
# Requirement already satisfied: psutil==6.1.0 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 36)) (6.1.0)
# Requirement already satisfied: ptyprocess==0.7.0 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 37)) (0.7.0)
# Requirement already satisfied: pure_eval==0.2.3 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 38)) (0.2.3)
# Requirement already satisfied: Pygments==2.18.0 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 39)) (2.18.0)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 40)) (2.9.0.post0)
# Requirement already satisfied: PyYAML==6.0.2 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 41)) (6.0.2)
# Requirement already satisfied: pyzmq==26.2.0 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 42)) (26.2.0)
# Requirement already satisfied: regex==2024.11.6 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 43)) (2024.11.6)
# Requirement already satisfied: requests==2.32.3 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 44)) (2.32.3)
# Requirement already satisfied: ruff==0.8.3 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 45)) (0.8.3)
# Requirement already satisfied: safetensors==0.4.5 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 46)) (0.4.5)
# Requirement already satisfied: seaborn==0.13.2 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 47)) (0.13.2)
# Requirement already satisfied: six==1.17.0 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 48)) (1.17.0)
# Requirement already satisfied: stack-data==0.6.3 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 49)) (0.6.3)
# Requirement already satisfied: sympy==1.13.1 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 50)) (1.13.1)
# Requirement already satisfied: tokenizers==0.21.0 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 51)) (0.21.0)
# Requirement already satisfied: torch==2.5.1+cu121 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 52)) (2.5.1+cu121)
# Requirement already satisfied: torchaudio==2.5.1+cu121 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 53)) (2.5.1+cu121)
# Requirement already satisfied: torchvision==0.20.1+cu121 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 54)) (0.20.1+cu121)
# Requirement already satisfied: tornado==6.4.2 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 55)) (6.4.2)
# Requirement already satisfied: tqdm==4.67.1 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 56)) (4.67.1)
# Requirement already satisfied: traitlets==5.14.3 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 57)) (5.14.3)
# Requirement already satisfied: transformers==4.47.1 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 58)) (4.47.1)
# Requirement already satisfied: triton==3.1.0 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 59)) (3.1.0)
# Requirement already satisfied: typing_extensions==4.12.2 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 60)) (4.12.2)
# Requirement already satisfied: urllib3==2.2.3 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 61)) (2.2.3)
# Requirement already satisfied: wcwidth==0.2.13 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 62)) (0.2.13)
# Requirement already satisfied: widgetsnbextension==4.0.13 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from -r requirements.txt (line 63)) (4.0.13)
# Requirement already satisfied: pytz>=2020.1 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from pandas==2.2.3->-r requirements.txt (line 30)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from pandas==2.2.3->-r requirements.txt (line 30)) (2024.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from seaborn==0.13.2->-r requirements.txt (line 47)) (3.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from torch==2.5.1+cu121->-r requirements.txt (line 52)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from torch==2.5.1+cu121->-r requirements.txt (line 52)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from torch==2.5.1+cu121->-r requirements.txt (line 52)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from torch==2.5.1+cu121->-r requirements.txt (line 52)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from torch==2.5.1+cu121->-r requirements.txt (line 52)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from torch==2.5.1+cu121->-r requirements.txt (line 52)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from torch==2.5.1+cu121->-r requirements.txt (line 52)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from torch==2.5.1+cu121->-r requirements.txt (line 52)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from torch==2.5.1+cu121->-r requirements.txt (line 52)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from torch==2.5.1+cu121->-r requirements.txt (line 52)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from torch==2.5.1+cu121->-r requirements.txt (line 52)) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.5.1+cu121->-r requirements.txt (line 52)) (12.1.105)
# Requirement already satisfied: contourpy>=1.0.1 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2->-r requirements.txt (line 47)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2->-r requirements.txt (line 47)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2->-r requirements.txt (line 47)) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2->-r requirements.txt (line 47)) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/bl/Documents/Teaching/busn-30135/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2->-r requirements.txt (line 47)) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 2. Setup HuggingFace Account
# HuggingFace (🤗) is an NYC-based start-up democratizing access to machine learning tools. They started out with an emphasis on transformer-based models but have been rapidly eating the ML world, producing tools that make it easier for anyone to leverage ML. Rather than rely on commercial models from a provider such as OpenAI, we will use open source models via HuggingFace.
#
# Using 🤗 has the added benefit that you do not need to be concerned with what a third-party might do with your data. This is a crucial benefit in the context of this course, i.e., financial intermediaries likely cannot pass client data through a third-party service such as OpenAI's APIs. Using 🤗 allows you to keep all data local and more easily comply with regulations.
#
# [Create an account here](https://huggingface.co/join)
#
# https://huggingface.co/docs/huggingface_hub/en/quick-start#authentication
#
# ### Log into HuggingFace Locally
# Now that you have a HuggingFace account, we want to make sure that code run from your Python environment is logged into your account. This requires you to create an access token.
#
# #### Create token
# Go [here](https://huggingface.co/settings/tokens) and click "+Create new token":
#
# ![image.png](.notebook_images/hf_create_token_0.png)
#
# On the following page, choose "Write" for the token type and click "Create token":
#
# ![image-2.png](.notebook_images/hf_create_token_1.png)
#
# You will then be presented with a token (a string of characters) which allows code to access your HuggingFace account. Save this somewhere for future use, as **you will not be able to see it again** and will need to create a new token per the process above if you lose it.
#
# #### Log in
# Run the command below to initiate the log in process, when prompted, copy and paste the token created above into the text box.

# %%
from huggingface_hub import login

login()

# %% [markdown]
# ## 3. Get Awesome Models For Free
# ### Request Access
# Meta provides open source models which rival commercial models such as OpenAI's LLMs. These models are "gated" in the sense that we must request access to them. Follow the links below to go to the model page and request access:
#
# - [Llama-3.2-1B-Instruct](https://huggingface.co/meta-llama/Llama-3.2-1B-Instruct)
# - [Llama-3.2-11B-Vision-Instruct](https://huggingface.co/meta-llama/Llama-3.2-11B-Vision-Instruct)
#
# Once you have been granted access--this usually happens within minutes of requesting access and can be checked by returning to the links above. If your request has been approved, you will see something like the image below:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Download Models
# The models below will take up about 30GB of storage, so you will want to make sure you have sufficient space for them.

# %%
from transformers import pipeline

model_ids = ["meta-llama/Llama-3.2-1B-Instruct", "meta-llama/Llama-3.2-11B-Vision-Instruct"]
for model_id in model_ids:
    pipe = pipeline("text-generation", model_id, device_map="auto")
# Out:
# Device set to use cuda:0
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# Some parameters are on the meta device because they were offloaded to the cpu.
# Device set to use cuda:0
